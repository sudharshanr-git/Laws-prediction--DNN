# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
from tensorflow.keras.regularizers import l2

tf.config.threading.set_inter_op_parallelism_threads(12)

# %%
@tf.keras.utils.register_keras_serializable()
def avg_recall(actual, pred):
    pred=tf.round(pred)
    class_recalls = []
    for i in range(actual.shape[1]):
        true_positives = tf.reduce_sum(tf.cast(tf.math.logical_and(tf.equal(actual[:, i], 1), tf.equal(pred[:, i], 1)), tf.float32))
        actual_positives = tf.reduce_sum(tf.cast(tf.equal(actual[:, i], 1), tf.float32))
        class_recalls.append(true_positives / (actual_positives + tf.keras.backend.epsilon()) )
    return tf.reduce_mean(class_recalls)

@tf.keras.utils.register_keras_serializable()
def avg_precision(actual, pred):
    pred=tf.round(pred)
    class_precisions = []
    for i in range(actual.shape[1]):
        tp = tf.reduce_sum(tf.cast(tf.math.logical_and(tf.equal(actual[:, i], 1), tf.equal(pred[:, i], 1)), tf.float32))
        positives=tf.reduce_sum(tf.cast(tf.equal(pred[:, i], 1), tf.float32))
        class_precisions.append(tp/(positives + tf.keras.backend.epsilon()))
    return tf.reduce_mean(class_precisions)

# %%
pretrained_model = tf.keras.models.load_model("v3.keras")
pretrained_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 384)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_8       │ (None, 384)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 500)       │    192,500 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 500)       │    192,500 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_6       │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 250)       │    125,250 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 250)       │    125,250 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 505)       │          0 │ input_layer_6[0]… │
# │ (Concatenate)       │                   │            │ dense_16[0][0],   │
# │                     │                   │            │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 250)       │    126,500 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 244)       │     61,244 │ dense_19[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,469,734 (9.42 MB)
#  Trainable params: 823,244 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,646,490 (6.28 MB)

# %%
#v3 - regularized

input_3 = Input(shape=(5,), name='law_area')
input_1 = Input(shape=(384,), name='facts')
input_2 = Input(shape=(384,), name='considerations')

b1 = Dense(500, activation='relu', name='facts_dense1', kernel_regularizer=l2(0.01))(input_1)
b1 = Dropout(0.3, name='facts_dropout1')(b1)
b1 = Dense(250, activation='relu', name='facts_dense2', kernel_regularizer=l2(0.01))(b1)

b2 = Dense(500, activation='relu', name='considerations_dense1', kernel_regularizer=l2(0.01))(input_2)
b2 = Dropout(0.3, name='considerations_dropout1')(b2)
b2 = Dense(250, activation='relu', name='considerations_dense2', kernel_regularizer=l2(0.01))(b2)

merged = Concatenate()([input_3, b1, b2])

output = Dense(250, activation='relu', name='concatenate_dense1', kernel_regularizer=l2(0.01))(merged)
output = Dropout(0.3, name='concatenate_dropout1')(output)
output = Dense(244, activation='sigmoid', name='output_layer', kernel_regularizer=l2(0.01))(output)

model = tf.keras.Model(inputs=[input_3,input_1,input_2], outputs=output)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[avg_recall, avg_precision])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ facts (InputLayer)  │ (None, 384)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ considerations      │ (None, 384)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ facts_dense1        │ (None, 500)       │    192,500 │ facts[0][0]       │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ considerations_den… │ (None, 500)       │    192,500 │ considerations[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ facts_dropout1      │ (None, 500)       │          0 │ facts_dense1[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ considerations_dro… │ (None, 500)       │          0 │ considerations_d… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ law_area            │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ facts_dense2        │ (None, 250)       │    125,250 │ facts_dropout1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ considerations_den… │ (None, 250)       │    125,250 │ considerations_d… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 505)       │          0 │ law_area[0][0],   │
# │ (Concatenate)       │                   │            │ facts_dense2[0][… │
# │                     │                   │            │ considerations_d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_dense1  │ (None, 250)       │    126,500 │ concatenate_1[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_dropou… │ (None, 250)       │          0 │ concatenate_dens… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_layer        │ (None, 244)       │     61,244 │ concatenate_drop… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 823,244 (3.14 MB)
#  Trainable params: 823,244 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.layers
# Out:
# [<InputLayer name=facts, built=True>,
#  <InputLayer name=considerations, built=True>,
#  <Dense name=facts_dense1, built=True>,
#  <Dense name=considerations_dense1, built=True>,
#  <InputLayer name=law_area, built=True>,
#  <Dense name=facts_dense2, built=True>,
#  <Dense name=considerations_dense2, built=True>,
#  <Concatenate name=concatenate, built=True>,
#  <Dense name=concatenate_dense1, built=True>,
#  <Dense name=output_layer, built=True>]

# %%
pretrained_model.layers
# Out:
# [<InputLayer name=input_layer_7, built=True>,
#  <InputLayer name=input_layer_8, built=True>,
#  <Dense name=dense_15, built=True>,
#  <Dense name=dense_17, built=True>,
#  <InputLayer name=input_layer_6, built=True>,
#  <Dense name=dense_16, built=True>,
#  <Dense name=dense_18, built=True>,
#  <Concatenate name=concatenate_2, built=True>,
#  <Dense name=dense_19, built=True>,
#  <Dense name=dense_20, built=True>]

# %%
model.layers[2].set_weights(pretrained_model.layers[2].get_weights())
model.layers[3].set_weights(pretrained_model.layers[3].get_weights())
model.layers[7].set_weights(pretrained_model.layers[5].get_weights())
model.layers[8].set_weights(pretrained_model.layers[6].get_weights())
model.layers[10].set_weights(pretrained_model.layers[8].get_weights())
model.layers[12].set_weights(pretrained_model.layers[9].get_weights())

# %%
model.layers[2].set_weights(pretrained_model.layers[2].get_weights())
model.layers[3].set_weights(pretrained_model.layers[3].get_weights())
model.layers[5].set_weights(pretrained_model.layers[5].get_weights())
model.layers[6].set_weights(pretrained_model.layers[6].get_weights())
model.layers[8].set_weights(pretrained_model.layers[8].get_weights())
model.layers[9].set_weights(pretrained_model.layers[9].get_weights())

# %%
df_train=pd.read_csv("sep_selected_laws_final_combined.csv").sample(frac=1) 
df_val=pd.read_csv("sep_selected_laws_final_val.csv")

#language_train=df_train.values[:,:3]
law_area_train=df_train.values[:,3:8]
facts_train=df_train.values[:,8:392]
considerations_train=df_train.values[:,392:776]
laws_train=df_train.values[:,776:]


#language_val=df_val.values[:,:3]
law_area_val=df_val.values[:,3:8]
facts_val=df_val.values[:,8:392]
considerations_val=df_val.values[:,392:776]
laws_val=df_val.values[:,776:]

# %%
ep=500
bs=1024

h = model.fit(
    [law_area_train, facts_train, considerations_train],
    laws_train,
    epochs=ep,
    batch_size=bs,
    validation_data=([law_area_val, facts_val, considerations_val], laws_val)
)
# Out:
# Epoch 1/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - avg_precision: 0.6660 - avg_recall: 0.6731 - loss: 0.0476 - val_avg_precision: 0.2215 - val_avg_recall: 0.2105 - val_loss: 0.0962
# Epoch 2/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0
500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - avg_precision: 0.7799 - avg_recall: 0.7345 - loss: 0.0064 - val_avg_precision: 0.2577 - val_avg_recall: 0.2178 - val_loss: 0.0741
# Epoch 22/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - avg_precision: 0.7899 - avg_recall: 0.7457 - loss: 0.0061 - val_avg_precision: 0.2500 - val_avg_recall: 0.2230 - val_loss: 0.0756
# Epoch 23/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.7891 - avg_recall: 0.7480 - loss: 0.0058 - val_avg_precision: 0.2499 - val_avg_recall: 0.2315 - val_loss: 0.0767
# Epoch 24/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.7938 - avg_recall: 0.7529 - loss: 0.0055 - val_avg_precision: 0.2538 - val_avg_recall: 0.2218 - val_loss: 0.0788
# Epoch 25/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.8002 - avg_recall: 0.7596 - loss: 0.0054 - val_avg_precision: 0.2507 - val_avg_recall: 0.2229 - val_loss: 0.0805
# Epoch 26/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.7994 - avg_recall: 0.7613 - loss: 0.0053 - val_avg_precision: 0.2430 - val_avg_recall: 0.2341 - val_loss: 0.0827
# Epoch 27/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - avg_precision: 0.7977 - avg_recall: 0.7655 - loss: 0.0047 - val_avg_precision: 0.2530 - val_avg_recall: 0.2400 - val_loss: 0.0826
# Epoch 28/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - avg_precision: 0.8072 - avg_recall: 0.7778 - loss: 0.0044 - val_avg_precision: 0.2534 - val_avg_recall: 0.2316 - val_loss: 0.0862
# Epoch 29/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - avg_precision: 0.8091 - avg_recall: 0.7770 - loss: 0.0042 - val_avg_precision: 0.2514 - val_avg_recall: 0.2366 - val_loss: 0.0866
# Epoch 30/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.8077 - avg_recall: 0.7764 - loss: 0.0042 - val_avg_precision: 0.2511 - val_avg_recall: 0.2301 - val_loss: 0.0882
# Epoch 31/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - avg_precision: 0.8119 - avg_recall: 0.7862 - loss: 0.0038 - val_avg_precision: 0.2496 - val_avg_recall: 0.2210 - val_loss: 0.0914
# Epoch 32/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.8134 - avg_recall: 0.7878 - loss: 0.0035 - val_avg_precision: 0.2476 - val_avg_recall: 0.2366 - val_loss: 0.0919
# Epoch 33/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - avg_precision: 0.8240 - avg_recall: 0.7974 - loss: 0.0037 - val_avg_precision: 0.2478 - val_avg_recall: 0.2339 - val_loss: 0.0936
# Epoch 34/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.8118 - avg_recall: 0.7875 - loss: 0.0034 - val_avg_precision: 0.2437 - val_avg_recall: 0.2341 - val_loss: 0.0957
# Epoch 35/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.8187 - avg_recall: 0.7962 - loss: 0.0031 - val_avg_precision: 0.2533 - val_avg_recall: 0.2389 - val_loss: 0.0985
# Epoch 36/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - avg_precision: 0.8170 - avg_recall: 0.7958 - loss: 0.0032 - val_avg_precision: 0.2513 - val_avg_recall: 0.2442 - val_loss: 0.0998
# Epoch 37/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - avg_precision: 0.8201 - avg_recall: 0.8016 - loss: 0.0029 - val_avg_precision: 0.2556 - val_avg_recall: 0.2316 - val_loss: 0.1028
# Epoch 38/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - avg_precision: 0.8223 - avg_recall: 0.8004 - loss: 0.0032 - val_avg_precision: 0.2485 - val_avg_recall: 0.2248 - val_loss: 0.1026
# Epoch 39/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - avg_precision: 0.8181 - avg_recall: 0.7993 - loss: 0.0028 - val_avg_precision: 0.2512 - val_avg_recall: 0.2321 - val_loss: 0.1045
# Epoch 40/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - avg_precision: 0
500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8176 - avg_recall: 0.8137 - loss: 0.0028 - val_avg_precision: 0.2410 - val_avg_recall: 0.2353 - val_loss: 0.1493
# Epoch 136/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8016 - avg_recall: 0.7884 - loss: 0.0044 - val_avg_precision: 0.2504 - val_avg_recall: 0.2366 - val_loss: 0.1509
# Epoch 137/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8271 - avg_recall: 0.8228 - loss: 0.0018 - val_avg_precision: 0.2483 - val_avg_recall: 0.2311 - val_loss: 0.1550
# Epoch 138/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8351 - avg_recall: 0.8331 - loss: 8.3365e-04 - val_avg_precision: 0.2495 - val_avg_recall: 0.2339 - val_loss: 0.1597
# Epoch 139/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8304 - avg_recall: 0.8290 - loss: 4.5813e-04 - val_avg_precision: 0.2535 - val_avg_recall: 0.2297 - val_loss: 0.1616
# Epoch 140/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8457 - avg_recall: 0.8448 - loss: 3.2799e-04 - val_avg_precision: 0.2557 - val_avg_recall: 0.2333 - val_loss: 0.1637
# Epoch 141/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8333 - avg_recall: 0.8320 - loss: 3.3213e-04 - val_avg_precision: 0.2576 - val_avg_recall: 0.2375 - val_loss: 0.1643
# Epoch 142/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8378 - avg_recall: 0.8371 - loss: 3.0147e-04 - val_avg_precision: 0.2526 - val_avg_recall: 0.2334 - val_loss: 0.1677
# Epoch 143/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8344 - avg_recall: 0.8340 - loss: 2.9079e-04 - val_avg_precision: 0.2577 - val_avg_recall: 0.2318 - val_loss: 0.1664
# Epoch 144/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8395 - avg_recall: 0.8385 - loss: 2.7445e-04 - val_avg_precision: 0.2528 - val_avg_recall: 0.2365 - val_loss: 0.1682
# Epoch 145/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8386 - avg_recall: 0.8380 - loss: 2.7929e-04 - val_avg_precision: 0.2547 - val_avg_recall: 0.2331 - val_loss: 0.1687
# Epoch 146/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8376 - avg_recall: 0.8370 - loss: 3.2806e-04 - val_avg_precision: 0.2535 - val_avg_recall: 0.2333 - val_loss: 0.1705
# Epoch 147/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8432 - avg_recall: 0.8423 - loss: 2.9088e-04 - val_avg_precision: 0.2537 - val_avg_recall: 0.2303 - val_loss: 0.1715
# Epoch 148/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8398 - avg_recall: 0.8392 - loss: 3.4500e-04 - val_avg_precision: 0.2547 - val_avg_recall: 0.2383 - val_loss: 0.1702
# Epoch 149/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8344 - avg_recall: 0.8333 - loss: 0.0013 - val_avg_precision: 0.2397 - val_avg_recall: 0.2218 - val_loss: 0.1340
# Epoch 150/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.7845 - avg_recall: 0.7723 - loss: 0.0060 - val_avg_precision: 0.2451 - val_avg_recall: 0.2368 - val_loss: 0.1516
# Epoch 151/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8266 - avg_recall: 0.8244 - loss: 9.8453e-04 - val_avg_precision: 0.2529 - val_avg_recall: 0.2298 - val_loss: 0.1578
# Epoch 152/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8388 - avg_recall: 0.8373 - loss: 4.6435e-04 - val_avg_precision: 0.2517 - val_avg_recall: 0.2292 - val_loss: 0.1607
# Epoch 153/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8406 - avg_recall: 0.8400 - loss: 2.9226e-04 - val_avg_precision: 0.2504 - val_avg_recall: 0.2326 - val_loss: 0.1630
# Epoch 154/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8417 - avg_recall: 0.8408 - loss: 2.9290e-04 - val_avg_precision: 0.2548 - val_avg_recall: 0.2329 - val_loss: 0.1652
# Epoch 155/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8380 - avg_recall: 0.8376 - loss: 2.5348e-04 - val_avg_precision: 0.2526 - val_avg_recall: 0.2347 - val_loss: 0.1662
# Epoch 156/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8503 - avg_recall: 0.8496 - loss: 2.6698e-04 - val_avg_precision: 0.2564 - val_avg_recall: 0.2332 - val_loss: 0.1674
# Epoch 157/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - avg_precision: 0.8410 - avg_recall: 0.8400 - loss: 2.8146e-04 - val_avg_precision: 0.2564 - val_avg_recall: 0.2325 - val_loss: 0.1686
# Epoch 158/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8384 - avg_recall: 0.8374 - loss: 2.5295e-04 - val_avg_precision: 0.2498 - val_avg_recall: 0.2308 - val_loss: 0.1700
# Epoch 159/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - avg_precision: 0.8375 - avg_recall: 0.8366 - loss: 2.6628e-04 - val_avg_precision: 0.2518 - val_avg_recall: 0.2358 - val_loss: 0.1700
# Epoch 160/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - avg_precision: 0.8411 - avg_recall: 0.8401 - loss: 3.0200e-04 - val_avg_precision: 0.2512 - val_avg_recall: 0.2361 - val_loss: 0.1701
# Epoch 161/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8466 - avg_recall: 0.8458 - loss: 2.5796e-04 - val_avg_precision: 0.2521 - val_avg_recall: 0.2274 - val_loss: 0.1711
# Epoch 162/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8412 - avg_recall: 0.8402 - loss: 3.0022e-04 - val_avg_precision: 0.2534 - val_avg_recall: 0.2331 - val_loss: 0.1696
# Epoch 163/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - avg_precision: 0.8373 - avg_recall: 0.8368 - loss: 2.9661e-04 - val_avg_precision: 0.2542 - val_avg_recall: 0.2318 - val_loss: 0.1704
# Epoch 164/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8331 - avg_recall: 0.8318 - loss: 3.7775e-04 - val_avg_precision: 0.2557 - val_avg_recall: 0.2325 - val_loss: 0.1700
# Epoch 165/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8327 - avg_recall: 0.8321 - loss: 4.8309e-04 - val_avg_precision: 0.2529 - val_avg_recall: 0.2278 - val_loss: 0.1711
# Epoch 166/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.7982 - avg_recall: 0.7942 - loss: 0.0050 - val_avg_precision: 0.2459 - val_avg_recall: 0.2308 - val_loss: 0.1545
# Epoch 167/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8067 - avg_recall: 0.8004 - loss: 0.0035 - val_avg_precision: 0.2495 - val_avg_recall: 0.2387 - val_loss: 0.1546
# Epoch 168/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8315 - avg_recall: 0.8295 - loss: 0.0014 - val_avg_precision: 0.2510 - val_avg_recall: 0.2317 - val_loss: 0.1603
# Epoch 169/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8343 - avg_recall: 0.8332 - loss: 5.6806e-04 - val_avg_precision: 0.2546 - val_avg_recall: 0.2289 - val_loss: 0.1632
# Epoch 170/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8353 - avg_recall: 0.8345 - loss: 3.4390e-04 - val_avg_precision: 0.2518 - val_avg_recall: 0.2343 - val_loss: 0.1653
# Epoch 171/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8412 - avg_recall: 0.8403 - loss: 2.6691e-04 - val_avg_precision: 0.2549 - val_avg_recall: 0.2310 - val_loss: 0.1687
# Epoch 172/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8333 - avg_recall: 0.8323 - loss: 2.5205e-04 - val_avg_precision: 0.2536 - val_avg_recall: 0.2355 - val_loss: 0.1684
# Epoch 173/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8388 - avg_recall: 0.8380 - loss: 2.7277e-04 - val_avg_precision: 0.2511 - val_avg_recall: 0.2274 - val_loss: 0.1715
# Epoch 174/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8481 - avg_recall: 0.8468 - loss: 2.6915e-04 - val_avg_precision: 0.2562 - val_avg_recall: 0.2312 - val_loss: 0.1717
# Epoch 175/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8450 - avg_recall: 0.8443 - loss: 2.5544e-04 - val_avg_precision: 0.2564 - val_avg_recall: 0.2320 - val_loss: 0.1719
# Epoch 176/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - avg_precision: 0.8402 - avg_recall: 0.8392 - loss: 2.8532e-04 - val_avg_precision: 0.2585 - val_avg_recall: 0.2338 - val_loss: 0.1722
# Epoch 177/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - avg_precision: 0.8299 - avg_recall: 0.8295 - loss: 2.9556e-04 - val_avg_precision: 0.2563 - val_avg_recall: 0.2287 - val_loss: 0.1725
# Epoch 178/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8368 - avg_recall: 0.8356 - loss: 3.8506e-04 - val_avg_precision: 0.2541 - val_avg_recall: 0.2345 - val_loss: 0.1736
# Epoch 179/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8340 - avg_recall: 0.8332 - loss: 3.1955e-04 - val_avg_precision: 0.2529 - val_avg_recall: 0.2302 - val_loss: 0.1748
# Epoch 180/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8395 - avg_recall: 0.8388 - loss: 2.9679e-04 - val_avg_precision: 0.2545 - val_avg_recall: 0.2370 - val_loss: 0.1742
# Epoch 181/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8346 - avg_recall: 0.8336 - loss: 3.5120e-04 - val_avg_precision: 0.2585 - val_avg_recall: 0.2246 - val_loss: 0.1720
# Epoch 182/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8208 - avg_recall: 0.8179 - loss: 0.0041 - val_avg_precision: 0.2516 - val_avg_recall: 0.2214 - val_loss: 0.1555
# Epoch 183/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8086 - avg_recall: 0.8022 - loss: 0.0033 - val_avg_precision: 0.2457 - val_avg_recall: 0.2375 - val_loss: 0.1590
# Epoch 184/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8265 - avg_recall: 0.8234 - loss: 0.0013 - val_avg_precision: 0.2494 - val_avg_recall: 0.2298 - val_loss: 0.1622
# Epoch 185/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8486 - avg_recall: 0.8469 - loss: 6.0468e-04 - val_avg_precision: 0.2467 - val_avg_recall: 0.2264 - val_loss: 0.1662
# Epoch 186/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8345 - avg_recall: 0.8336 - loss: 3.4388e-04 - val_avg_precision: 0.2588 - val_avg_recall: 0.2350 - val_loss: 0.1685
# Epoch 187/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8323 - avg_recall: 0.8311 - loss: 2.7813e-04 - val_avg_precision: 0.2555 - val_avg_recall: 0.2355 - val_loss: 0.1712
# Epoch 188/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8429 - avg_recall: 0.8422 - loss: 2.4447e-04 - val_avg_precision: 0.2554 - val_avg_recall: 0.2291 - val_loss: 0.1722
# Epoch 189/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8400 - avg_recall: 0.8394 - loss: 2.4070e-04 - val_avg_precision: 0.2541 - val_avg_recall: 0.2325 - val_loss: 0.1725
# Epoch 190/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8440 - avg_recall: 0.8426 - loss: 2.5429e-04 - val_avg_precision: 0.2565 - val_avg_recall: 0.2334 - val_loss: 0.1734
# Epoch 191/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8346 - avg_recall: 0.8336 - loss: 2.6386e-04 - val_avg_precision: 0.2546 - val_avg_recall: 0.2348 - val_loss: 0.1737
# Epoch 192/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.
500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8359 - avg_recall: 0.8350 - loss: 3.1289e-04 - val_avg_precision: 0.2521 - val_avg_recall: 0.2294 - val_loss: 0.1768
# Epoch 212/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8342 - avg_recall: 0.8312 - loss: 0.0012 - val_avg_precision: 0.2500 - val_avg_recall: 0.2155 - val_loss: 0.1696
# Epoch 213/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8061 - avg_recall: 0.7995 - loss: 0.0043 - val_avg_precision: 0.2415 - val_avg_recall: 0.2393 - val_loss: 0.1626
# Epoch 214/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8134 - avg_recall: 0.8062 - loss: 0.0029 - val_avg_precision: 0.2552 - val_avg_recall: 0.2333 - val_loss: 0.1638
# Epoch 215/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8329 - avg_recall: 0.8294 - loss: 8.1860e-04 - val_avg_precision: 0.2525 - val_avg_recall: 0.2283 - val_loss: 0.1678
# Epoch 216/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - avg_precision: 0.8335 - avg_recall: 0.8323 - loss: 3.3886e-04 - val_avg_precision: 0.2557 - val_avg_recall: 0.2344 - val_loss: 0.1702
# Epoch 217/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8371 - avg_recall: 0.8364 - loss: 2.5769e-04 - val_avg_precision: 0.2595 - val_avg_recall: 0.2316 - val_loss: 0.1738
# Epoch 218/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8437 - avg_recall: 0.8427 - loss: 2.7606e-04 - val_avg_precision: 0.2566 - val_avg_recall: 0.2309 - val_loss: 0.1758
# Epoch 219/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8415 - avg_recall: 0.8404 - loss: 2.3603e-04 - val_avg_precision: 0.2564 - val_avg_recall: 0.2274 - val_loss: 0.1740
# Epoch 220/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8436 - avg_recall: 0.8425 - loss: 2.5021e-04 - val_avg_precision: 0.2573 - val_avg_recall: 0.2347 - val_loss: 0.1750
# Epoch 221/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8321 - avg_recall: 0.8313 - loss: 2.5213e-04 - val_avg_precision: 0.2592 - val_avg_recall: 0.2347 - val_loss: 0.1773
# Epoch 222/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8357 - avg_recall: 0.8351 - loss: 2.2959e-04 - val_avg_precision: 0.2570 - val_avg_recall: 0.2304 - val_loss: 0.1774
# Epoch 223/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - avg_precision: 0.8369 - avg_recall: 0.8362 - loss: 2.6580e-04 - val_avg_precision: 0.2583 - val_avg_recall: 0.2289 - val_loss: 0.1779
# Epoch 224/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - avg_precision: 0.8429 - avg_recall: 0.8419 - loss: 2.4773e-04 - val_avg_precision: 0.2573 - val_avg_recall: 0.2322 - val_loss: 0.1781
# Epoch 225/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8380 - avg_recall: 0.8373 - loss: 2.6401e-04 - val_avg_precision: 0.2562 - val_avg_recall: 0.2327 - val_loss: 0.1797
# Epoch 226/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - avg_precision: 0.8385 - avg_recall: 0.8379 - loss: 2.7741e-04 - val_avg_precision: 0.2595 - val_avg_recall: 0.2344 - val_loss: 0.1787
# Epoch 227/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - avg_precision: 0.8348 - avg_recall: 0.8339 - loss: 2.6864e-04 - val_avg_precision: 0.2561 - val_avg_recall: 0.2359 - val_loss: 0.1782
# Epoch 228/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8306 - avg_recall: 0.8295 - loss: 3.1106e-04 - val_avg_precision: 0.2576 - val_avg_recall: 0.2280 - val_loss: 0.1792
# Epoch 229/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - avg_precision: 0.8356 - avg_recall: 0.8347 - loss: 5.4477e-04 - val_avg_precision: 0.2473 - val_avg_recall: 0.2050 - val_loss: 0.1605
# Epoch 230/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.7752 - avg_recall: 0.7639 - loss: 0.0073 - val_avg_precision: 0.2506 - val_avg_recall: 0.2278 - val_loss: 0.1597
# Epoch 231/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8177 - avg_recall: 0.8130 - loss: 0.0016 - val_avg_precision: 0.2479 - val_avg_recall: 0.2355 - val_loss: 0.1652
# Epoch 232/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8301 - avg_recall: 0.8278 - loss: 5.9705e-04 - val_avg_precision: 0.2526 - val_avg_recall: 0.2305 - val_loss: 0.1699
# Epoch 233/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8389 - avg_recall: 0.8378 - loss: 2.9989e-04 - val_avg_precision: 0.2545 - val_avg_recall: 0.2270 - val_loss: 0.1726
# Epoch 234/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8435 - avg_recall: 0.8425 - loss: 2.3118e-04 - val_avg_precision: 0.2580 - val_avg_recall: 0.2306 - val_loss: 0.1745
# Epoch 235/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8438 - avg_recall: 0.8430 - loss: 2.0807e-04 - val_avg_precision: 0.2540 - val_avg_recall: 0.2260 - val_loss: 0.1762
# Epoch 236/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8401 - avg_recall: 0.8394 - loss: 2.3236e-04 - val_avg_precision: 0.2531 - val_avg_recall: 0.2272 - val_loss: 0.1777
# Epoch 237/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8350 - avg_recall: 0.8340 - loss: 2.1684e-04 - val_avg_precision: 0.2587 - val_avg_recall: 0.2281 - val_loss: 0.1770
# Epoch 238/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8360 - avg_recall: 0.8351 - loss: 2.6217e-04 - val_avg_precision: 0.2554 - val_avg_recall: 0.2324 - val_loss: 0.1768
# Epoch 239/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8393 - avg_recall: 0.8386 - loss: 2.3997e-04 - val_avg_precision: 0.2572 - val_avg_recall: 0.2293 - val_loss: 0.1783
# Epoch 240/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8427 - avg_recall: 0.8416 - loss: 2.5613e-04 - val_avg_precision: 0.2536 - val_avg_recall: 0.2346 - val_loss: 0.1766
# Epoch 241/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8371 - avg_recall: 0.8364 - loss: 2.7813e-04 - val_avg_precision: 0.2545 - val_avg_recall: 0.2313 - val_loss: 0.1785
# Epoch 242/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8337 - avg_recall: 0.8328 - loss: 2.4933e-04 - val_avg_precision: 0.2537 - val_avg_recall: 0.2276 - val_loss: 0.1781
# Epoch 243/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8450 - avg_recall: 0.8446 - loss: 2.8200e-04 - val_avg_precision: 0.2484 - val_avg_recall: 0.2310 - val_loss: 0.1811
# Epoch 244/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - avg_precision: 0.8380 - avg_recall: 0.8368 - loss: 3.8264e-04 - val_avg_precision: 0.2531 - val_avg_recall: 0.2320 - val_loss: 0.1774
# Epoch 245/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8333 - avg_recall: 0.8306 - loss: 0.0014 - val_avg_precision: 0.2420 - val_avg_recall: 0.2325 - val_loss: 0.1642
# Epoch 246/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8034 - avg_recall: 0.7973 - loss: 0.0043 - val_avg_precision: 0.2449 - val_avg_recall: 0.2428 - val_loss: 0.1647
# Epoch 247/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8194 - avg_recall: 0.8156 - loss: 0.0022 - val_avg_precision: 0.2479 - val_avg_recall: 0.2269 - val_loss: 0.1670
# Epoch 248/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8341 - avg_recall: 0.8325 - loss: 7.2784e-04 - val_avg_precision: 0.2520 - val_avg_recall: 0.2365 - val_loss: 0.1701
# Epoch 249/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8435 - avg_recall: 0.8424 - loss: 3.3710e-04 - val_avg_precision: 0.2495 - val_avg_recall: 0.2278 - val_loss: 0.1741
# Epoch 250/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8440 - avg_recall: 0.8429 - loss: 2.2881e-04 - val_avg_precision: 0.2513 - val_avg_recall: 0.2294 - val_loss: 0.1753
# Epoch 251/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8308 - avg_recall: 0.8301 - loss: 2.2803e-04 - val_avg_precision: 0.2517 - val_avg_recall: 0.2303 - val_loss: 0.1758
# Epoch 252/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8416 - avg_recall: 0.8407 - loss: 2.1356e-04 - val_avg_precision: 0.2512 - val_avg_recall: 0.2267 - val_loss: 0.1785
# Epoch 253/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8385 - avg_recall: 0.8377 - loss: 2.4989e-04 - val_avg_precision: 0.2529 - val_avg_recall: 0.2255 - val_loss: 0.1793
# Epoch 254/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8345 - avg_recall: 0.8333 - loss: 2.2152e-04 - val_avg_precision: 0.2507 - val_avg_recall: 0.2244 - val_loss: 0.1804
# Epoch 255/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8427 - avg_recall: 0.8419 - loss: 2.4634e-04 - val_avg_precision: 0.2501 - val_avg_recall: 0.2315 - val_loss: 0.1786
# Epoch 256/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8288 - avg_recall: 0.8281 - loss: 2.4454e-04 - val_avg_precision: 0.2491 - val_avg_recall: 0.2283 - val_loss: 0.1792
# Epoch 257/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8353 - avg_recall: 0.8343 - loss: 2.6304e-04 - val_avg_precision: 0.2564 - val_avg_recall: 0.2325 - val_loss: 0.1801
# Epoch 258/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8337 - avg_recall: 0.8330 - loss: 2.7768e-04 - val_avg_precision: 0.2530 - val_avg_recall: 0.2301 - val_loss: 0.1801
# Epoch 259/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8416 - avg_recall: 0.8409 - loss: 2.8188e-04 - val_avg_precision: 0.2457 - val_avg_recall: 0.2359 - val_loss: 0.1809
# Epoch 260/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8379 - avg_recall: 0.8369 - loss: 3.1350e-04 - val_avg_precision: 0.2507 - val_avg_recall: 0.2269 - val_loss: 0.1814
# Epoch 261/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8402 - avg_recall: 0.8390 - loss: 3.4755e-04 - val_avg_precision: 0.2467 - val_avg_recall: 0.2321 - val_loss: 0.1628
# Epoch 262/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8163 - avg_recall: 0.8115 - loss: 0.0040 - val_avg_precision: 0.2423 - val_avg_recall: 0.2274 - val_loss: 0.1662
# Epoch 263/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8191 - avg_recall: 0.8141 - loss: 0.0023 - val_avg_precision: 0.2460 - val_avg_recall: 0.2371 - val_loss: 0.1671
# Epoch 264/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - avg_precision: 0.8264 - avg_recall: 0.8251 - loss: 0.0013 - val_avg_precision: 0.2460 - val_avg_recall: 0.2217 - val_loss: 0.1729
# Epoch 265/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - avg_precision: 0.8403 - avg_recall: 0.8386 - loss: 5.3610e-04 - val_avg_precision: 0.2550 - val_avg_recall: 0.2296 - val_loss: 0.1732
# Epoch 266/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8428 - avg_recall: 0.8425 - loss: 3.0199e-04 - val_avg_precision: 0.2560 - val_avg_recall: 0.2357 - val_loss: 0.1752
# Epoch 267/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - avg_precision: 0.8462 - avg_recall: 0.8453 - loss: 2.4343e-04 - val_avg_precision: 0.2559 - val_avg_recall: 0.2306 - val_loss: 0.1772
# Epoch 268/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8444 - avg_recall: 0.8436 - loss: 2.0367e-04 - val_avg_precision: 0.2532 - val_avg_recall: 0.2353 - val_loss: 0.1780
# Epoch 269/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8344 - avg_recall: 0.8338 - loss: 2.0532e-04 - val_avg_precision: 0.2591 - val_avg_recall: 0.2258 - val_loss: 0.1801
# Epoch 270/500
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - avg_precision: 0.8434 - avg_recall: 0.8429 - loss: 2.4882e-04 - val_avg_precision: 0.2560 - val_avg_recall: 0.2260 - val_loss: 0.1804
# Epoch 271/500
#  72/103 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - avg_precision: 0.8347 - avg_recall: 0.8338 - loss: 2.0651e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      11 ep=500
#      12 bs=1024
# ---> 14 h = model.fit(
#      15     [law_area_train, facts_train, considerations_train],
#      16     laws_train,
#      17     epochs=ep,
#      18     batch_size=bs,
#      19     validation_data=([law_area_val, facts_val, considerations_val], laws_val)
#      20 )
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:368, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     366 for step, iterator in epoch_iterator:
#     367     callbacks.on_train_batch_begin(step)
# --> 368     logs = self.train_function(iterator)
#     369     callbacks.on_train_batch_end(step, logs)
#     370     if self.stop_training:
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:216, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     212 def function(iterator):
#     213     if isinstance(
#     214         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     215     ):
# --> 216         opt_outputs = multi_step_on_iterator(iterator)
#     217         if not opt_outputs.has_value():
#     218             raise StopIteration
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\RS7un\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
def calculate_recprec(actual, prediction):
    recall=[]
    precision=[]
    total_laws=actual[0].shape[0]
    for law in range(total_laws):
        recaller=tf.keras.metrics.Recall()
        recaller.update_state(actual[:,law].tolist(),prediction[:,law].tolist())
        recall.append(float(recaller.result().numpy()))
        
        precisioner=tf.keras.metrics.Precision()
        precisioner.update_state(actual[:,law].tolist(),prediction[:,law].tolist())
        precision.append(float(precisioner.result().numpy()))
    
    '''
    print("Individual recall:")
    print(recall)
    print("Individual precision:")
    print(precision)
    '''
    
    print("Average recall:", sum(recall)/total_laws)
    print("Average precision:", sum(precision)/total_laws)

# %%
def give_results(model):
    train_prediction=(model.predict([law_area_train, facts_train, considerations_train],batch_size=1024) > 0.5).astype(int)
    val_prediction=(model.predict([law_area_val, facts_val, considerations_val],batch_size=1024) > 0.5).astype(int)

    print("Training set:")
    calculate_recprec(laws_train, train_prediction)
    print("Validdation set:")
    calculate_recprec(laws_val, val_prediction)
    print("Epochs:",500)
    print("Batch size:",bs)

# %%
give_results(model)
print("--------------")
give_results(pretrained_model)
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training set:
# Average recall: 0.998098035572005
# Average precision: 0.9997083332206382
# Validdation set:
# Average recall: 0.2786484530012383
# Average precision: 0.33644203455416394
# Epochs: 500
# Batch size: 1024
# --------------
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training set:
# Average recall: 0.8320960539286254
# Average precision: 0.8949690685897577
# Validdation set:
# Average recall: 0.23318577614292257
# Average precision: 0.3090214709537562
# Epochs: 500
# Batch size: 1024

# %%
model.save("v3_unregularized_newdata_overfit")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
